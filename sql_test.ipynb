# %% [markdown]
# # SQLite Test Notebook
#
# This notebook connects directly to the local `demo.db` SQLite database and runs a simple query.

# %%
import sqlite3

# %%
conn = sqlite3.connect("demo.db")
cursor = conn.cursor()

# %%
query = "SELECT * FROM people"
cursor.execute(query)
rows = cursor.fetchall()
rows
# Out:
# [(1, 'Rafal Nadal', 35, 'Tennis Player'),
#  (2, 'Rafal Nadal', 35, 'Tennis Player')]

# %%
conn.close()
